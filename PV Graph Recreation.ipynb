# %% [markdown]
# # PV plot recreation

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('data.csv', sep=None, engine='python')

# Replace Unnamed headers with empty strings
data.columns = [col if 'Unnamed' not in col else '' for col in data.columns]

data.head()  # Display the first few rows to verify

# Extract the 2002 column
o2years = data.iloc[:, 0] #the second colum (Years)
# Extract the added capacity column
added_capacity_o2years = data.iloc[:, 1]  # Select the third column (index 2)

o4years = data.iloc[:, 2]  # The third column
added_capacity_o4years = data.iloc[:, 3]  # The fourth column
o6years = data.iloc[:, 4]  
added_capacity_o6years = data.iloc[:, 5]
o8years = data.iloc[:, 7]  
added_capacity_o8years = data.iloc[:, 8]
o9years = data.iloc[:, 9]  
added_capacity_o9years = data.iloc[:, 10]
o10years = data.iloc[:, 11]  
added_capacity_o10years = data.iloc[:, 12]
o11years = data.iloc[:, 13]  
added_capacity_o11years = data.iloc[:, 14]
o12years = data.iloc[:, 15]  
added_capacity_o12years = data.iloc[:, 16]
o13years = data.iloc[:, 17]  
added_capacity_o13years = data.iloc[:, 18]
o14years = data.iloc[:, 19]  
added_capacity_o14years = data.iloc[:, 20]
o15years = data.iloc[:, 21]  
added_capacity_o15years = data.iloc[:, 22]
o16years = data.iloc[:, 23]  
added_capacity_o16years = data.iloc[:, 24]
o17years = data.iloc[:, 25]  
added_capacity_o17years = data.iloc[:, 26]

# Plot the data
plt.figure(figsize=(10, 6))
# Plot each column with a label for the legend


plt.plot(o2years, added_capacity_o2years, label='WEO 2002 REF')
plt.plot(o4years, added_capacity_o4years, label = 'WEO 2004 REF')
plt.plot(o6years, added_capacity_o6years, label = 'WEO 2006 REF')
plt.plot(o8years, added_capacity_o8years, label = 'WEO 2008 REF')
plt.plot(o9years, added_capacity_o9years, label='WEO 2009 REF')
plt.plot(o10years, added_capacity_o10years, label = 'WEO 2010 NPS')
plt.plot(o11years, added_capacity_o11years, label = 'WEO 2011 NPS')
plt.plot(o12years, added_capacity_o12years, label = 'WEO 2012 NPS')
plt.plot(o13years, added_capacity_o13years, label = 'WEO 2013 NPS')
plt.plot(o14years, added_capacity_o14years, label='WEO 20014 NPS')
plt.plot(o15years, added_capacity_o15years, label='WEO 20015 NPS')
plt.plot(o16years, added_capacity_o16years, label = 'WEO 2016 NPS')
plt.plot(o17years, added_capacity_o17years, label = 'WEO 2017 New Policies (NPS)')
#plt.plot(o8years, added_capacity_o18years, label = 'WEO 2018 REF')
#plt.plot(o2years, added_capacity_o19years, label='WEO 2019 REF')
#plt.plot(o4years, added_capacity_o20years, label = 'WEO 2020 REF')
#plt.plot(o6years, added_capacity_o21years, label = 'WEO 2021 REF')
#plt.plot(o8years, added_capacity_o22years, label = 'WEO 2022 REF')
#plt.plot(o6years, added_capacity_o23years, label = 'WEO 2023 REF')
#plt.plot(o8years, added_capacity_o24years, label = 'WEO 2024 REF')

# Add labels and title
plt.title('Annual PV additions: historic data vs IEA WEO predictions', fontsize=16, y=1.04)

# Add subtitle below the title
plt.text(
    0.5, 1.02, 'In GW of added capacity per year - source International Energy Agency - World Energy Outlook', 
    fontsize=12, color='gray', ha='center', transform=plt.gca().transAxes
)

# Add grid and legend
plt.grid(alpha=0.3)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

data.head()  # Display the first few rows to verify
# Out:
#     ﻿2002         2004         2006             2008          2009  ...  \
# 0  1999.0  0.0  2003.0  1.0  2005.0  1.0 NaN  2007.0   3.0  2008.0  ...
# 1  2010.0  1.0  2010.0  1.0  2015.0  3.0 NaN  2015.0   3.0  2015.0  ...
# 2  2020.0  1.0  2020.0  2.0  2030.0  7.0 NaN  2020.0   7.0  2020.0  ...
# 3  2030.0  4.0  2030.0  5.0     NaN  0.0 NaN  2025.0  11.0  2025.0  ...
# 4     NaN  NaN     NaN  NaN     NaN  NaN NaN  2030.0  16.0  2030.0  ...
#
#      2013        2014      2015      2016        2017
# 0  2012.0  30.0  2013  37  2014  40  2015  50  2016.0  75.0
# 1  2020.0  27.0  2020  32  2020  37  2020  51  2025.0  71.0
# 2  2025.0  25.0  2025  28  2025  33  2025  47  2030.0  73.0
# 3  2030.0  25.0  2030  28  2030  34  2030  47  2035.0  77.0
# 4  2035.0  25.0  2035  29  2035  34  2035  47  2040.0  76.0
#
# [5 rows x 27 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('data.csv', sep=None, engine='python')

# Replace Unnamed headers with empty strings
data.columns = [col if 'Unnamed' not in col else '' for col in data.columns]

data.head()  # Display the first few rows to verify

# Extract the 2002 column
o2years = data.iloc[:, 0] #the second colum (Years)
# Extract the added capacity column
added_capacity_o2years = data.iloc[:, 1]  # Select the third column (index 2)

o4years = data.iloc[:, 2]  # The third column
added_capacity_o4years = data.iloc[:, 3]  # The fourth column
o6years = data.iloc[:, 4]  
added_capacity_o6years = data.iloc[:, 5]
o8years = data.iloc[:, 7]  
added_capacity_o8years = data.iloc[:, 8]
o9years = data.iloc[:, 9]  
added_capacity_o9years = data.iloc[:, 10]
o10years = data.iloc[:, 11]  
added_capacity_o10years = data.iloc[:, 12]
o11years = data.iloc[:, 13]  
added_capacity_o11years = data.iloc[:, 14]
o12years = data.iloc[:, 15]  
added_capacity_o12years = data.iloc[:, 16]
o13years = data.iloc[:, 17]  
added_capacity_o13years = data.iloc[:, 18]
o14years = data.iloc[:, 19]  
added_capacity_o14years = data.iloc[:, 20]
o15years = data.iloc[:, 21]  
added_capacity_o15years = data.iloc[:, 22]
o16years = data.iloc[:, 23]  
added_capacity_o16years = data.iloc[:, 24]
o17years = data.iloc[:, 25]  
added_capacity_o17years = data.iloc[:, 26]

# Plot the data
plt.figure(figsize=(10, 6))
# Plot each column with a label for the legend

# Define points for the arrow path
arrow_x = [o2years.iloc[0], o4years.iloc[0], o6years.iloc[0], o8years.iloc[0]]  # x-coordinates (start, intermediate, ..., end)
arrow_y = [added_capacity_o2years.iloc[0], added_capacity_o4years.iloc[0], added_capacity_o6years.iloc[0], added_capacity_o8years.iloc[0]]  # y-coordinates (start, intermediate, ..., end)

# Draw the path connecting all points
plt.plot(arrow_x, arrow_y, linestyle='--', color='black')


plt.plot(o2years, added_capacity_o2years, label='WEO 2002 REF')
plt.plot(o4years, added_capacity_o4years, label = 'WEO 2004 REF')
plt.plot(o6years, added_capacity_o6years, label = 'WEO 2006 REF')
plt.plot(o8years, added_capacity_o8years, label = 'WEO 2008 REF')
plt.plot(o9years, added_capacity_o9years, label='WEO 2009 REF')
plt.plot(o10years, added_capacity_o10years, label = 'WEO 2010 NPS')
plt.plot(o11years, added_capacity_o11years, label = 'WEO 2011 NPS')
plt.plot(o12years, added_capacity_o12years, label = 'WEO 2012 NPS')
plt.plot(o13years, added_capacity_o13years, label = 'WEO 2013 NPS')
plt.plot(o14years, added_capacity_o14years, label='WEO 20014 NPS')
plt.plot(o15years, added_capacity_o15years, label='WEO 20015 NPS')
plt.plot(o16years, added_capacity_o16years, label = 'WEO 2016 NPS')
plt.plot(o17years, added_capacity_o17years, label = 'WEO 2017 New Policies (NPS)')
#plt.plot(o8years, added_capacity_o18years, label = 'WEO 2018 REF')
#plt.plot(o2years, added_capacity_o19years, label='WEO 2019 REF')
#plt.plot(o4years, added_capacity_o20years, label = 'WEO 2020 REF')
#plt.plot(o6years, added_capacity_o21years, label = 'WEO 2021 REF')
#plt.plot(o8years, added_capacity_o22years, label = 'WEO 2022 REF')
#plt.plot(o6years, added_capacity_o23years, label = 'WEO 2023 REF')
#plt.plot(o8years, added_capacity_o24years, label = 'WEO 2024 REF')

# Add labels and title
plt.title('Annual PV additions: historic data vs IEA WEO predictions', fontsize=16, y=1.04)

# Add subtitle below the title
plt.text(
    0.5, 1.02, 'In GW of added capacity per year - source International Energy Agency - World Energy Outlook', 
    fontsize=12, color='gray', ha='center', transform=plt.gca().transAxes
)

# Add grid and legend
plt.grid(alpha=0.3)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

data.head()  # Display the first few rows to verify
# Out:
#     ﻿2002         2004         2006             2008          2009  ...  \
# 0  1999.0  0.0  2003.0  1.0  2005.0  1.0 NaN  2007.0   3.0  2008.0  ...
# 1  2010.0  1.0  2010.0  1.0  2015.0  3.0 NaN  2015.0   3.0  2015.0  ...
# 2  2020.0  1.0  2020.0  2.0  2030.0  7.0 NaN  2020.0   7.0  2020.0  ...
# 3  2030.0  4.0  2030.0  5.0     NaN  0.0 NaN  2025.0  11.0  2025.0  ...
# 4     NaN  NaN     NaN  NaN     NaN  NaN NaN  2030.0  16.0  2030.0  ...
#
#      2013        2014      2015      2016        2017
# 0  2012.0  30.0  2013  37  2014  40  2015  50  2016.0  75.0
# 1  2020.0  27.0  2020  32  2020  37  2020  51  2025.0  71.0
# 2  2025.0  25.0  2025  28  2025  33  2025  47  2030.0  73.0
# 3  2030.0  25.0  2030  28  2030  34  2030  47  2035.0  77.0
# 4  2035.0  25.0  2035  29  2035  34  2035  47  2040.0  76.0
#
# [5 rows x 27 columns]
